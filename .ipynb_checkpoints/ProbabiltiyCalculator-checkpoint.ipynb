# %%
# !pip install matplotlib
# !pip install transformers scikit-learn
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: pip in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (24.0)
# Collecting pip
#   Using cached pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-24.3.1-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (4.46.3)
# Requirement already satisfied: scikit-learn in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: filelock in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.7.4)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (2.5.1)
# Requirement already satisfied: torchvision in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (0.20.1)
# Requirement already satisfied: torchaudio in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupyter in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: ipywidgets in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (8.1.5)
# Requirement already satisfied: notebook in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: jupyterlab in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (4.2.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (1.8.9)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (75.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: webencodings in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.4.0)
# Requirement already satisfied: certifi in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.5)
# Requirement already satisfied: idna in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.2)
# Requirement already satisfied: fqdn in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\harri\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241003)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\harri\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import matplotlib.pyplot as plt

# Initialize the tokenizer and model
model_name = "gpt2"  # Use GPT-2 for next-word prediction
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Set pad_token to be eos_token since GPT-2 doesn't have a pad token by default
tokenizer.pad_token = tokenizer.eos_token  # Use EOS token as padding token

def predict_correct_probability(length, complexity, alpha=0.01):
    """
    Calculate the probability of predicting the correct next word.
    """
    return 1 / (1 + alpha * length * complexity)

def calculate_prompt_length(prompt):
    """
    Calculate the number of tokens in a prompt (approximated as words).
    """
    return len(prompt.split())

def estimate_complexity(prompt):
    """
    Estimate the complexity of a prompt using basic linguistic features.
    """
    words = prompt.split()
    num_words = len(words)
    unique_words = len(set(words))
    avg_word_length = sum(len(word) for word in words) / num_words if num_words > 0 else 0

    # Lexical complexity approximation
    lexical_complexity = (avg_word_length * 0.5) + (unique_words / num_words * 2)

    return lexical_complexity

def get_next_token(prompt):
    """
    Generate the next token for a given prompt using GPT-2.
    """
    inputs = tokenizer(prompt, return_tensors="pt")
    with torch.no_grad():
        logits = model(**inputs).logits
    
    predicted_token_id = torch.argmax(logits[0, -1, :]).item()
    predicted_token = tokenizer.decode(predicted_token_id, skip_special_tokens=False)
    
    return predicted_token

def plot_probability_over_steps(prompt, alpha=0.01, max_steps=5):
    """
    Simulate the prediction of the next token and plot the probability of correct next token.
    """
    full_prompt = prompt
    probabilities = []  # To store probabilities over steps

    for step in range(max_steps):
        # Generate the next token
        next_token = get_next_token(full_prompt)

        # Calculate length and complexity for the current prompt
        length = calculate_prompt_length(full_prompt)
        complexity = estimate_complexity(full_prompt)
        
        # Calculate the probability of correctly predicting the next token
        probability = predict_correct_probability(length, complexity, alpha)
        probabilities.append(probability)

        # Display current step details
        print(f"Step {step + 1}:")
        print(f"Prompt: {full_prompt}")
        print(f"Next token: {next_token}")
        print(f"Probability of correct next token: {probability:.4f}")
        print("-" * 50)

        # Append the next token to the prompt
        full_prompt += next_token

    # Plotting the probabilities
    plt.plot(range(1, max_steps + 1), probabilities, marker='o', linestyle='-', color='b')
    plt.title('Probability of Correct Next Token Over Steps')
    plt.xlabel('Step')
    plt.ylabel('Probability')
    plt.grid(True)
    plt.show()

# Main Code
prompt = input("Enter your prompt: ")
alpha = float(input("Enter the model's sensitivity factor alpha (default 0.01): ") or 0.01)
plot_probability_over_steps(prompt, alpha)
